# %%
#  Loading 
import pandas as pd
from sqlalchemy import create_engine

# %%
# pip install pandas openpyxl sqlalchemy pymysql

# %%
from sqlalchemy.engine import URL 
from sqlalchemy import create_engine
from getpass import getpass

url = URL.create(
    drivername="mysql+pymysql",
    username = "root",
    password = getpass("Enter MySQL password: "), # Prompt user for password
    host="localhost",
    port=3306,
    database="ecommerce_analytics"
)

engine = create_engine(url)
# Out:
# Enter MySQL password:  ········

# %%
# Excel File Path
file_path = "../Datasets/Normalized Super Store1.xlsx"

# Read workbook
excel_file = pd.ExcelFile(file_path)

# Load each sheet into MySQL
for sheet in excel_file.sheet_names:
    df = pd.read_excel(file_path, sheet_name=sheet)

    # Clean table name
    table_name = sheet.lower()

    # Write to MySQL
    df.to_sql(
        name=table_name,
        con=engine,
        if_exists="fail",
        index=False
    )

    print(f"Loaded {sheet} into table '{table_name}'")

print("All sheets loaded successfully!")
# Out:
# Loaded Locations into table 'locations'
# Loaded Sales Reps into table 'sales reps'
# All sheets loaded successfully!

# %%
file_path = "dataset path"

excel_file = pd.ExcelFile(file_path)

#read the excel files to pandas
for sheet in excel_file.sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet)
    # clean table names
    table_name = sheet.lower()

    # load to sql
    df.to_sql(
        name= table_name,
        con= engine,
        if_exits = "replace",
        index = False
    )

    print(f"{sheet} loaded to {table_name}"

print("All tables loaded successfully to MySQL"
